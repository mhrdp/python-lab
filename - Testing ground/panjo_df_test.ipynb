# %%
import pandas as pd

file = '/content/drive/MyDrive/Program/Python/- Testing ground/panjo.csv'

panjo = pd.read_csv(file)
a = '1. Dine In	'
b = '1. Dine in	'
dine_in = panjo.loc[panjo['Sales Type'] == '1. Dine In']
outlet = panjo[panjo['Outlet'].isin(['Borma Cikutra'])]

# Formatting all columns
# lambda can be used for custom processing of all fields
panj = panjo.apply(lambda x: x.astype(str).str.lower())

# Formatting specifict columns
for col in panjo.columns:
    if col == 'Sales Type' or col == 'Outlet':
        panjo[col] = panjo[col].str.lower()
    panjo[col] = panjo[col]

# Filtering based on columns value
dine_in = panjo.loc[panjo['Sales Type'] == '1. dine in']
dine_in_net_sales = dine_in[['Net Sales']].sum()



# Filter based on all of different categories and sum it
sales_type = []
sales = {}
for i in set(panjo['Sales Type']):
    sales_type.append(i)

    sum_by_sales_type = panjo.loc[panjo['Sales Type'] == i]['Net Sales'].sum()
    sales[i] = [sum_by_sales_type]
df_sales = pd.DataFrame(sales)

outlet_name = []
outlet_sales = {}
for i in set(panjo['Outlet']):
    outlet_name.append(i)

    sum_by_outlet = panjo.loc[panjo['Outlet'] == i]['Net Sales'].sum()
    outlet_sales[i] = [sum_by_outlet]
df_outlet =  pd.DataFrame(outlet_sales)

TU_count = panjo.loc[panjo['Outlet'] == 'teuku umar']['Outlet'].count()

for i in df_outlet.columns:
    print(f'{i} : {df_outlet[i][0]}')

# Filter a dataset 'Item' column value that starts with 'full refund' and 'partial refund'
drop_full_refund = panj.loc[panj['Items'].str.startswith('full refund')]
drop_partial_refund = panj.loc[panj['Items'].str.startswith('partial refund')]

# drop the row indexes that has 'full refund' as a value in one of its column 
panj.drop(index=drop_full_refund.index, inplace=True)
panj.drop(index=drop_partial_refund.index, inplace=True)

num_of_items_sold = len(set(panj['Items']))

# Count the number of appearance of 'Items' column value in the entire dataframe
# The result is unique
count_intems_value = panj['Items'].value_counts()

panj.groupby(pd.Grouper(key='Date', axis=0, freq='2D', sort=True)).sum()
# Out:
# borma cikutra : 19640550.0
# gegerkalong hilir : 50099050.0
# teuku umar : 42523250.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-aad862e8b32a> in <module>()
#      63 count_intems_value = panj['Items'].value_counts()
#      64
# ---> 65 panj.groupby(pd.Grouper(key='Date', axis=0, freq='2D', sort=True)).sum()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
