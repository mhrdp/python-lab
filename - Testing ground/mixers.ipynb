# %%
import numpy

BIN = '/content/drive/MyDrive/Program/Python/- Testing ground/$1$SC0510.BIN'
f = open(BIN)
rectype = numpy.dtype([('x', '<u8'), ('y', '<u8'),
                       ('z', '<u8'), ('bar', '<i4', 256)])
numpy.fromfile(f, dtype=bin)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-5e2c350afc38> in <module>()
#       5 rectype = numpy.dtype([('x', '<u8'), ('y', '<u8'),
#       6                        ('z', '<u8'), ('bar', '<i4', 256)])
# ----> 7 numpy.fromfile(f, dtype=bin)
#
# TypeError: Cannot interpret '<built-in function bin>' as a data type

# %%
i = 'Hello'
i = i.replace(' ', '+').lower()
''.join([x for x in i])
# Out:
# 'hello'

# %%
test_dict = ['Helen', 'Babe']
print(list(zip(*test_dict)))
# Out:
# [('H', 'B'), ('e', 'a'), ('l', 'b'), ('e', 'e')]

# %%
from collections import defaultdict

d = defaultdict(str)
d[0] = d[0] + 'Baba'
d[1] = d[1] + 'Booba'
print(d)
# Out:
# defaultdict(<class 'str'>, {0: 'Baba', 1: 'Booba'})

# %%
l = ['flower', 'flicker', 'flow']

d = []
for i in zip(*l):
  print(i)
# Out:
# ('f', 'f', 'f')
# ('l', 'l', 'l')
# ('o', 'i', 'o')
# ('w', 'c', 'w')
