# %%
s = [1,8,6,2,5,4,8,3,7]

print(sorted(s)[::-1])
# Out:
# [8, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
l = ['flower', 'flicker', 'flow']

d = []
for i in zip(*l):
  print(i)
# Out:
# ('f', 'f', 'f')
# ('l', 'l', 'l')
# ('o', 'i', 'o')
# ('w', 'c', 'w')
