# %%
l = [''] * 4
l
# Out:
# ['', '', '', '']

# %%
from collections import defaultdict

d = defaultdict(str)
d[0] = d[0] + 'Baba'
d[1] = d[1] + 'Booba'
print(d)
# Out:
# defaultdict(<class 'str'>, {0: 'Baba', 1: 'Booba'})

# %%
l = ['flower', 'flicker', 'flow']

d = []
for i in zip(*l):
  print(i)
# Out:
# ('f', 'f', 'f')
# ('l', 'l', 'l')
# ('o', 'i', 'o')
# ('w', 'c', 'w')
